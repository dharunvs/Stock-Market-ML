# %%
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler 
from keras.models import Sequential 
from keras.layers import Dense, LSTM, Dropout
import pandas_datareader as web

# %%
start = dt.datetime(2012, 1, 1)
end = dt.datetime(2022, 1, 1)

start_test = dt.datetime(2022, 1, 1)
end_test = dt.datetime(2022, 10, 1)

company = 'TSLA'

data = web.DataReader(company, 'yahoo', start, end)
test_data = web.DataReader(company, 'yahoo', start_test, end_test)

data["Close"] = pd.to_numeric(data.Close, errors="coerce")
data = data.dropna()
trainData = data.iloc[:, 4:5].values

test_data["Close"] = pd.to_numeric(test_data.Close, errors="coerce")
test_data = test_data.dropna()
testData = test_data.iloc[:, 4:5].values

print(trainData)
print(testData)
# Out:
# [[13921500.]
#  [ 9451500.]
#  [15082500.]
#  ...
#  [56154000.]
#  [47040900.]
#  [40733700.]]
# [[4.073370e+07]
#  [1.039314e+08]
#  [1.002483e+08]
#  [8.011980e+07]
#  [9.033660e+07]
#  [8.416470e+07]
#  [9.181500e+07]
#  [6.606330e+07]
#  [8.373900e+07]
#  [9.720990e+07]
#  [7.292430e+07]
#  [6.674340e+07]
#  [7.544250e+07]
#  [7.048860e+07]
#  [1.034160e+08]
#  [1.515657e+08]
#  [8.659590e+07]
#  [1.048674e+08]
#  [1.471095e+08]
#  [1.347891e+08]
#  [1.044360e+08]
#  [7.313820e+07]
#  [6.679290e+07]
#  [7.885560e+07]
#  [7.362540e+07]
#  [6.099450e+07]
#  [5.072910e+07]
#  [5.225940e+07]
#  [6.612690e+07]
#  [7.964580e+07]
#  [6.775650e+07]
#  [5.728620e+07]
#  [5.129430e+07]
#  [5.517840e+07]
#  [6.850170e+07]
#  [8.328810e+07]
#  [9.525690e+07]
#  [1.353222e+08]
#  [7.606770e+07]
#  [9.900690e+07]
#  [7.476690e+07]
#  [7.464330e+07]
#  [6.162360e+07]
#  [6.699960e+07]
#  [7.249410e+07]
#  [8.039910e+07]
#  [5.918400e+07]
#  [5.864850e+07]
#  [6.703710e+07]
#  [7.115220e+07]
# ...

# %%
data.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [50], line 1
# ----> 1 scaled_data.info()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'info'

# %%
sc = MinMaxScaler (feature_range=(0,1))
trainData = sc.fit_transform(trainData)
trainData.shape

# %%
X_train =[]
y_train =[]
for i in range (60,1149):
    X_train.append(trainData[i-60:i,0])
    y_train.append(trainData[i,0])
                             
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train = np.reshape (X_train, (X_train.shape[0],X_train.shape [1],1)) #adding the batch_size axis
X_train.shape

# %%
model = Sequential()
model.add(LSTM(units=100, return_sequences = True, input_shape =(X_train.shape[1],1)))
model.add(Dropout(0.2))
model.add(LSTM(units=100, return_sequences = True))
model.add(Dropout(0.2))
model.add (LSTM(units=100, return_sequences = True))
model.add (Dropout(0.2))
model.add(LSTM(units=100, return_sequences = False))
model.add(Dropout(0.2))
model.add(Dense(units =1))
model.compile(optimizer='adam', loss="mean_squared_error")

# %%
hist = model.fit(X_train, y_train, epochs = 20, batch_size = 32, verbose=2)
# Out:
# Epoch 1/20
# 35/35 - 4s - loss: 0.0034 - 4s/epoch - 107ms/step
# Epoch 2/20
# 35/35 - 4s - loss: 0.0030 - 4s/epoch - 107ms/step
# Epoch 3/20
# 35/35 - 4s - loss: 0.0027 - 4s/epoch - 107ms/step
# Epoch 4/20
# 35/35 - 4s - loss: 0.0027 - 4s/epoch - 110ms/step
# Epoch 5/20
# 35/35 - 4s - loss: 0.0028 - 4s/epoch - 108ms/step
# Epoch 6/20
# 35/35 - 4s - loss: 0.0027 - 4s/epoch - 108ms/step
# Epoch 7/20
# 35/35 - 4s - loss: 0.0028 - 4s/epoch - 107ms/step
# Epoch 8/20
# 35/35 - 4s - loss: 0.0027 - 4s/epoch - 108ms/step
# Epoch 9/20
# 35/35 - 4s - loss: 0.0027 - 4s/epoch - 108ms/step
# Epoch 10/20
# 35/35 - 4s - loss: 0.0027 - 4s/epoch - 111ms/step
# Epoch 11/20
# 35/35 - 4s - loss: 0.0026 - 4s/epoch - 109ms/step
# Epoch 12/20
# 35/35 - 4s - loss: 0.0029 - 4s/epoch - 110ms/step
# Epoch 13/20
# 35/35 - 4s - loss: 0.0032 - 4s/epoch - 109ms/step
# Epoch 14/20
# 35/35 - 4s - loss: 0.0028 - 4s/epoch - 110ms/step
# Epoch 15/20
# 35/35 - 4s - loss: 0.0027 - 4s/epoch - 110ms/step
# Epoch 16/20
# ...

# %%
plt.plot(hist.history['loss'])
plt.title("Training model loss")
plt.ylabel('loss')
plt.xlabel ('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
testData = pd.read_csv('Google test_data.csv')
testData["Close"]=pd.to_numeric(testData.Close,errors='coerce')
testData = testData.dropna ()
testData = testData.iloc [: ,4:5]
y_test = testData.iloc [60:, 0:].values
#input array for the model
inputclosing = testData. iloc[:, e:].values
inputClosing_scaled = sc.transform(inputClosing)
inputClosing_scaled.shape
X_test = []
length = len (testData)
timestep = 60
for i in range(timestep‚length):
X_test.append (inputClosing_scaled[i-timestep:i,e])
X_test = np.array (X_test)
X_test = np. reshape (X_test, (X_test.shape[e],X_test.shape [1],1))
X_test.shape

# %%
y_pred = model.predict (X_test)

# %%
predicted_price = sc.inverse_transform(y_pred)

# %%
[pIt.plot(y_test, color = 'red', label = 'Actual Stock Price")
plt.plot(predicted_price, color = 'green', label = 'Predicted Stock Price')
pit. title('Google stock price prediction')
plt.xlabel ('Time', plt.ylabel('Stock Price' pit. legend () pit.show()
